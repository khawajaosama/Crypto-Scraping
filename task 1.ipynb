# %% [markdown]
# # Panacloud BootCamp Tasks:

# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg' 
plt.style.use('fivethirtyeight')

# %% [markdown]
# # TASK 1

# %%
current=requests.get('https://api.coinmarketcap.com/v1/ticker/').json()

# %%
print(current)
# Out:
# [{'id': 'bitcoin', 'name': 'Bitcoin', 'symbol': 'BTC', 'rank': '1', 'price_usd': '7951.67', 'price_btc': '1.0', '24h_volume_usd': '7183060000.0', 'market_cap_usd': '134542455192', 'available_supply': '16920025.0', 'total_supply': '16920025.0', 'max_supply': '21000000.0', 'percent_change_1h': '1.89', 'percent_change_24h': '-13.43', 'percent_change_7d': '-19.82', 'last_updated': '1521098666'}, {'id': 'ethereum', 'name': 'Ethereum', 'symbol': 'ETH', 'rank': '2', 'price_usd': '591.32', 'price_btc': '0.0746953', '24h_volume_usd': '2024200000.0', 'market_cap_usd': '58066215290.0', 'available_supply': '98197618.0', 'total_supply': '98197618.0', 'max_supply': None, 'percent_change_1h': '1.65', 'percent_change_24h': '-14.66', 'percent_change_7d': '-21.68', 'last_updated': '1521098652'}, {'id': 'ripple', 'name': 'Ripple', 'symbol': 'XRP', 'rank': '3', 'price_usd': '0.659136', 'price_btc': '0.00008326', '24h_volume_usd': '649201000.0', 'market_cap_usd': '25766757657.0', 'available_supply': '39091716516.0', 'total_supply': '99992497246.0', 'max_supply': '100000000000', 'percent_change_1h': '1.68', 'percent_change_24h': '-16.47', 'percent_change_7d': '-24.18', 'last_updated': '1521098641'}, {'id': 'bitcoin-cash', 'name': 'Bitcoin Cash', 'symbol': 'BCH', 'rank': '4', 'price_usd': '897.062', 'price_btc': '0.113317', '24h_volume_usd': '412101000.0', 'market_cap_usd': '15266716927.0', 'available_supply': '17018575.0', 'total_supply': '17018575.0', 'max_supply': '21000000.0', 'percent_change_1h': '2.12', 'percent_change_24h': '-13.86', 'percent_change_7d': '-17.32', 'last_updated': '1521098652'}, {'id': 'litecoin', 'name': 'Litecoin', 'symbol': 'LTC', 'rank': '5', 'price_usd': '155.934', 'price_btc': '0.0196976', '24h_volume_usd': '549111000.0', 'market_cap_usd': '8675353959.0', 'available_supply': '55634781.0', 'total_supply': '55634781.0', 'max_supply': '84000000.0', 'percent_change_1h': '2.74', 'percent_change_24h': '-10.58', 'percent_change_7d': '-15.11', 'last_updated': '1521098641'}, {'id': 'cardano', 'name': 'Cardano', 'symbol': 'ADA', 'rank': '6', 'price_usd': '0.178048', 'price_btc': '0.00002249', '24h_volume_usd': '174569000.0', 'market_cap_usd': '4616263055.0', 'available_supply': '25927070538.0', 'total_supply': '31112483745.0', 'max_supply': '45000000000.0', 'percent_change_1h': '2.58', 'percent_change_24h': '-22.25', 'percent_change_7d': '-25.39', 'last_updated': '1521098653'}, {'id': 'neo', 'name': 'NEO', 'symbol': 'NEO', 'rank': '7', 'price_usd': '67.9466', 'price_btc': '0.00858299', '24h_volume_usd': '173162000.0', 'market_cap_usd': '4416529000.0', 'available_supply': '65000000.0', 'total_supply': '100000000.0', 'max_supply': '100000000.0', 'percent_change_1h': '3.54', 'percent_change_24h': '-18.36', 'percent_change_7d': '-31.1', 'last_updated': '1521098647'}, {'id': 'stellar', 'name': 'Stellar', 'symbol': 'XLM', 'rank': '8', 'price_usd': '0.225925', 'price_btc': '0.00002854', '24h_volume_usd': '58103200.0', 'market_cap_usd': '4179315054.0', 'available_supply': '18498683431.0', 'total_supply': '103768249378', 'max_supply': None, 'percent_change_1h': '3.37', 'percent_change_24h': '-22.21', 'percent_change_7d': '-29.96', 'last_updated': '1521098643'}, {'id': 'eos', 'name': 'EOS', 'symbol': 'EOS', 'rank': '9', 'price_usd': '5.03076', 'price_btc': '0.00063548', '24h_volume_usd': '292735000.0', 'market_cap_usd': '3665631884.0', 'available_supply': '728643760.0', 'total_supply': '900000000.0', 'max_supply': '1000000000.0', 'percent_change_1h': '2.89', 'percent_change_24h': '-14.08', 'percent_change_7d': '-22.49', 'last_updated': '1521098651'}, {'id': 'monero', 'name': 'Monero', 'symbol': 'XMR', 'rank': '10', 'price_usd': '210.029', 'price_btc': '0.0265308', '24h_volume_usd': '85734700.0', 'market_cap_usd': '3323886268.0', 'available_supply': '15825844.0', 'total_supply': '15825844.0', 'max_supply': None, 'percent_change_1h': '1.82', 'percent_change_24h': '-15.41', 'percent_change_7d': '-33.81', 'last_updated': '1521098642'}, {'id': ' ...

# %% [markdown]
# # Task 2

# %%
dec_6=pd.read_csv('coinmarketcap_06122017.csv')
dec_6
# Out:
#       Unnamed: 0  24h_volume_usd  available_supply                 id  \
# 0              0    9.007640e+09      1.672352e+07            bitcoin
# 1              1    1.551330e+09      9.616537e+07           ethereum
# 2              2    1.111350e+09      1.684044e+07       bitcoin-cash
# 3              3    2.936090e+09      2.779530e+09               iota
# 4              4    2.315050e+08      3.873915e+10             ripple
# 5              5    2.289430e+08      7.736420e+06               dash
# 6              6    4.093420e+08      5.415391e+07           litecoin
# 7              7    1.384070e+08      1.669097e+07       bitcoin-gold
# 8              8    5.498600e+08      1.544296e+07             monero
# 9              9    6.164750e+07      2.592707e+10            cardano
# 10            10    4.020670e+08      9.812566e+07   ethereum-classic
# 11            11    3.172850e+07      9.000000e+09                nem
# 12            12    2.490480e+08      5.199591e+08                eos
# 13            13    1.133520e+08      6.500000e+07                neo
# 14            14    2.578380e+08      1.783388e+10            stellar
# 15            15    1.257440e+08      5.581722e+07           monacoin
# 16            16    2.459810e+07      3.185692e+06         bitconnect
# 17            17    6.965980e+07      1.156410e+08               lisk
# 18            18    1.896010e+08      2.774181e+06              zcash
# 19            19    6.003860e+07      1.020426e+08            omisego
# 20            20    1.421220e+08      7.369633e+07               qtum
# 21            21    1.084790e+09      8.140173e+08             tether
# 22            22    4.676660e+07      1.000000e+08              waves
# 23            23    3.733400e+07      9.864974e+07            stratis
# 24            24    1.567790e+06      4.125225e+07           populous
# 25            25    7.814140e+07      4.233708e+07             hshare
# 26            26    9.387460e+06      9.989995e+08              ardor
# 27            27    1.733630e+07      2.603860e+09          bitshares
# 28            28    6.102460e+06      1.832535e+11       bytecoin-bcn
# 29            29    2.077010e+07      9.798128e+07                ark
# ...          ...             ...               ...                ...
# ...            ...             ...           ...                ...
# 1296    1512549556             NaN           NaN           Wowecoin
# 1297    1512549575             NaN           NaN             BITFID
# 1298    1512416645             NaN           NaN          VegasCoin
# 1299    1512388746             NaN           NaN     GameLeagueCoin
# 1300    1512236350             NaN           NaN         BitCentavo
# 1301    1512515050             NaN           NaN          CyberCoin
# 1302    1512445464             NaN           NaN            EggCoin
# 1303    1512462250             NaN           NaN          ShellCoin
# 1304    1512385451             NaN           NaN       DeltaCredits
# 1305    1512464652             NaN           NaN             Cashme
# 1306    1512548652             NaN           NaN                 X2
# 1307    1512499755             NaN           NaN           Opescoin
# 1308    1512516857             NaN           NaN       BitAlphaCoin
# 1309    1512473656             NaN           NaN         Psilocybin
# 1310    1512290953             NaN           NaN               OCOW
# 1311    1512494057             NaN           NaN           SafeCoin
# 1312    1512499760             NaN           NaN           PokeCoin
# 1313    1512274759             NaN           NaN         SportsCoin
# 1314    1512525562             NaN           NaN            Omicron
# 1315    1512538164             NaN           NaN            PinkDog
# 1316    1511625871             NaN           NaN           TeraCoin
# 1317    1512533665             NaN           NaN            ZSEcoin
# 1318    1512256762             NaN           NaN               BIXC
# 1319    1512485969             NaN           NaN           Tyrocoin
# 1320    1512545967             NaN  2.941134e+06             PiCoin
# 1321    1512368664             NaN           NaN          TurboCoin
# 1322    1512535772             NaN           NaN              Birds
# 1323    1512548078             NaN           NaN  BitcoinCashScrypt
# 1324    1512540278             NaN           NaN          Swisscoin
# 1325    1512435283             NaN           NaN          Faceblock
#
#       percent_change_1h  percent_change_24h  percent_change_7d     price_btc  \
# 0                  0.12                7.33              17.45  1.000000e+00
# 1                 -0.18               -3.93              -7.33  3.617670e-02
# 2                  1.65               -5.51              -4.75  1.200500e-01
# 3                 -2.38               83.35             255.82  4.241800e-04
# 4                  0.56               -3.70             -14.79  1.932000e-05
# 5                  1.22               -3.31              10.64  5.985610e-02
# 6                 -0.17                0.80               3.68  8.315530e-03
# 7                 -0.86               -8.65             -11.24  2.355880e-02
# 8                 -2.00               25.65              41.23  2.241770e-02
# 9                 -0.28               -5.80              -8.25  9.960000e-06
# 10                -0.20               -3.47              -7.70  2.334760e-03
# 11                -0.70               -0.39              14.56  2.295000e-05
# 12                 2.26               29.56              69.66  3.946600e-04
# 13                 1.24               -7.28               0.20  3.016000e-03
# 14                -2.71               39.48              51.09  1.079000e-05
# 15                17.10              109.98             251.44  1.603050e-03
# 16                 0.49                3.70              15.49  2.776020e-02
# 17                 1.06               -2.52              15.79  7.234900e-04
# 18                -0.99                9.00              -2.20  2.824040e-02
# 19                -0.72               -8.06               3.93  7.501900e-04
# 20                 0.36               -9.85             -16.12  9.920800e-04
# 21                 0.17               -0.07              -0.06  8.002000e-05
# 22                 0.97               -4.33              22.21  5.645000e-04
# 23                 1.48               -6.64              16.87  5.638000e-04
# 24                -0.39               16.05              48.46  1.266230e-03
# 25                 0.24               -9.33             -18.18  1.229030e-03
# 26                 1.28               -6.55              52.61  4.364000e-05
# 27                 4.99                9.20               9.18  1.465000e-05
# 28                -2.43                0.39              26.99  1.800000e-07
# 26    5.459780e-01    27   ARDR  9.989995e+08
# 27    1.832490e-01    28    BTS  2.603860e+09
# 28    2.282360e-03    29    BCN  1.832535e+11
# 29    4.249210e+00    30    ARK  1.292313e+08
# ...            ...   ...    ...           ...
# 1296  1.020000e-01  1297    WEC  8.901692e+06
# 1297  1.251230e-01  1298    FID           NaN
# 1298  1.120000e-04  1299    VGC           NaN
# 1299  8.832210e-03  1300    GML           NaN
# 1300  3.269000e-07  1301    NBE           NaN
# 1301  1.176560e-04  1302     CC  5.492675e+08
# 1302  4.410930e-02  1303    EGG           NaN
# 1303  2.337040e-02  1304  SHELL  9.174170e+07
# 1304  1.718640e-01  1305   DCRE           NaN
# 1305  1.184620e-04  1306    CME           NaN
# 1306  1.247080e-04  1307     X2           NaN
# 1307  2.461290e-03  1308   OPES           NaN
# 1308  3.769280e-03  1309    BAC           NaN
# 1309  2.126970e-02  1310    PSY           NaN
# 1310  4.898870e-03  1311   OCOW           NaN
# 1311  1.163760e-04  1312    SFE           NaN
# 1312  2.344090e-04  1313   POKE           NaN
# 1313  1.215830e-03  1314  SPORT  1.980000e+07
# 1314  1.343190e-01  1315    OMC  1.014004e+07
# 1315  1.221060e-04  1316    PDG           NaN
# 1316  8.607040e-05  1317   TERA  9.223372e+10
# 1317  1.124870e-02  1318    ZSE  6.768156e+06
# 1318  4.411970e+00  1319   BIXC  2.100000e+08
# 1319  1.770120e-03  1320    TYC  5.062930e+07
# 1320  2.737830e-03  1321     PI  1.378369e+06
# 1321  1.144930e-04  1322  TURBO           NaN
# 1322  1.219770e-04  1323  BIRDS           NaN
# 1323  6.201720e-03  1324   BCCS  2.502380e+06
# 1324  1.229050e-04  1325    SIC  1.020000e+10
# 1325  1.654310e-03  1326    FBL  1.000000e+07
#
# [1326 rows x 16 columns]

# %%
raw_market=dec_6[['id','market_cap_usd']]
raw_market
# Out:
#                      id  market_cap_usd
# 0               bitcoin    2.130493e+11
# 1              ethereum    4.352945e+10
# 2          bitcoin-cash    2.529585e+10
# 3                  iota    1.475225e+10
# 4                ripple    9.365343e+09
# 5                  dash    5.794076e+09
# 6              litecoin    5.634498e+09
# 7          bitcoin-gold    4.920065e+09
# 8                monero    4.331688e+09
# 9               cardano    3.231420e+09
# 10     ethereum-classic    2.866555e+09
# 11                  nem    2.583927e+09
# 12                  eos    2.567610e+09
# 13                  neo    2.452898e+09
# 14              stellar    2.407074e+09
# 15             monacoin    1.119571e+09
# 16           bitconnect    1.106525e+09
# 17                 lisk    1.046840e+09
# 18                zcash    9.802597e+08
# 19              omisego    9.578316e+08
# 20                 qtum    9.147999e+08
# 21               tether    8.150593e+08
# 22                waves    7.063190e+08
# 23              stratis    6.959148e+08
# 24             populous    6.535758e+08
# 25               hshare    6.510596e+08
# 26                ardor    5.454317e+08
# 27            bitshares    4.771547e+08
# 28         bytecoin-bcn    4.182505e+08
# 29                  ark    4.163431e+08
# ...                 ...             ...
# 1296           wowecoin             NaN
# 1297             bitfid             NaN
# 1298          vegascoin             NaN
# 1299     gameleaguecoin             NaN
# 1300         bitcentavo             NaN
# 1301          cybercoin             NaN
# 1302            eggcoin             NaN
# 1303          shellcoin             NaN
# 1304       deltacredits             NaN
# 1305             cashme             NaN
# 1306                 x2             NaN
# 1307           opescoin             NaN
# 1308       bitalphacoin             NaN
# 1309         psilocybin             NaN
# 1310               ocow             NaN
# 1311           safecoin             NaN
# 1312           pokecoin             NaN
# 1313         sportscoin             NaN
# 1314            omicron             NaN
# 1315            pinkdog             NaN
# 1316           teracoin             NaN
# 1317            zsecoin             NaN
# 1318               bixc             NaN
# 1319           tyrocoin             NaN
# 1320             picoin             NaN
# 1321          turbocoin             NaN
# 1322              birds             NaN
# 1323  bitcoincashscrypt             NaN
# 1324          swisscoin             NaN
# 1325          faceblock             NaN
#
# [1326 rows x 2 columns]

# %%
print('The No of id are ' + str(raw_market['id'].count()))
# Out:
# The No of id are 1326

# %%
print('The No of market_cap_usd are ' + str(raw_market['market_cap_usd'].count()))
# Out:
# The No of market_cap_usd are 1031

# %% [markdown]
# # Task No 3:

# %% [markdown]
# ###  Discard the cryptocurrencies without a market capitalization

# %%
without_cap=raw_market.query('market_cap_usd>0')
without_cap
# Out:
#                            id  market_cap_usd
# 0                     bitcoin    2.130493e+11
# 1                    ethereum    4.352945e+10
# 2                bitcoin-cash    2.529585e+10
# 3                        iota    1.475225e+10
# 4                      ripple    9.365343e+09
# 5                        dash    5.794076e+09
# 6                    litecoin    5.634498e+09
# 7                bitcoin-gold    4.920065e+09
# 8                      monero    4.331688e+09
# 9                     cardano    3.231420e+09
# 10           ethereum-classic    2.866555e+09
# 11                        nem    2.583927e+09
# 12                        eos    2.567610e+09
# 13                        neo    2.452898e+09
# 14                    stellar    2.407074e+09
# 15                   monacoin    1.119571e+09
# 16                 bitconnect    1.106525e+09
# 17                       lisk    1.046840e+09
# 18                      zcash    9.802597e+08
# 19                    omisego    9.578316e+08
# 20                       qtum    9.147999e+08
# 21                     tether    8.150593e+08
# 22                      waves    7.063190e+08
# 23                    stratis    6.959148e+08
# 24                   populous    6.535758e+08
# 25                     hshare    6.510596e+08
# 26                      ardor    5.454317e+08
# 27                  bitshares    4.771547e+08
# 28               bytecoin-bcn    4.182505e+08
# 29                        ark    4.163431e+08
# ...                       ...             ...
# 1001               selfiecoin    1.349200e+04
# 1002                   p7coin    1.322100e+04
# 1003              gbcgoldcoin    1.292800e+04
# 1004                      das    1.244400e+04
# 1005                 rsgpcoin    1.226600e+04
# 1006                  bitvolt    1.134600e+04
# 1007     morningstar-payments    9.672000e+03
# 1008          socialcoin-socc    9.530000e+03
# 1009                 frazcoin    9.382000e+03
# 1010                 nodecoin    8.400000e+03
# 1011                  concoin    6.705000e+03
# 1012               burstocean    5.865000e+03
# 1013                  ccminer    5.277000e+03
# 1014                project-x    4.896000e+03
# 1015     wallet-builders-coin    4.256000e+03
# 1016                  lex4all    3.900000e+03
# 1017            ebittree-coin    3.643000e+03
# 1018                  sojourn    3.514000e+03
# 1019                pizzacoin    2.931000e+03
# 1020                   enigma    2.303000e+03
# 1021                  ulatech    2.302000e+03
# 1022                swaptoken    2.288000e+03
# 1023          digital-credits    2.187000e+03
# 1024       digital-money-bits    5.150000e+02
# 1025               mantracoin    5.140000e+02
# 1026  future-digital-currency    2.510000e+02
# 1027                  environ    1.360000e+02
# 1028               caliphcoin    1.000000e+02
# 1029                  falcoin    2.300000e+01
# 1030            applecoin-apw    1.000000e+01
#
# [1031 rows x 2 columns]

# %%
print('Again counting the rows of market cap usd = ' + str(without_cap['id'].count()))
# Out:
# Again counting the rows of market cap usd = 1031

# %% [markdown]
# # Task No 4:

# %% [markdown]
# ## Compairing Bitcoin compared with the rest of the cryptocurrencies

# %%
TOP_CAP_TITLE = 'Top 10 market capitalization'
TOP_CAP_YLABEL = '% of total cap'

x_axis=without_cap['id'].head(10)
capital=without_cap['market_cap_usd'].head(10)
print(capital)
x_axis
# Out:
# 0    2.130493e+11
# 1    4.352945e+10
# 2    2.529585e+10
# 3    1.475225e+10
# 4    9.365343e+09
# 5    5.794076e+09
# 6    5.634498e+09
# 7    4.920065e+09
# 8    4.331688e+09
# 9    3.231420e+09
# Name: market_cap_usd, dtype: float64
# 0         bitcoin
# 1        ethereum
# 2    bitcoin-cash
# 3            iota
# 4          ripple
# 5            dash
# 6        litecoin
# 7    bitcoin-gold
# 8          monero
# 9         cardano
# Name: id, dtype: object

# %%
y_axis=(capital/sum(capital))*100
y_axis
# Out:
# 0    64.579199
# 1    13.194580
# 2     7.667641
# 3     4.471679
# 4     2.838809
# 5     1.756291
# 6     1.707920
# 7     1.491363
# 8     1.313015
# 9     0.979503
# Name: market_cap_usd, dtype: float64

# %%
raw=np.arange(10)
plt.bar(raw,y_axis)
plt.xticks(raw,x_axis,fontsize=10,rotation=45)
plt.xlabel(TOP_CAP_TITLE)
plt.ylabel(TOP_CAP_YLABEL)

plt.show()

# %% [markdown]
# # Task No 5:

# %% [markdown]
# ## Making the plot easier to read and more informative

# %%
plt.bar(raw,y_axis,log=True,color=['orange', 'green', 'orange', 'cyan', 'cyan', 'blue', 'silver', 'orange', 'red', 'green'])
plt.xticks(raw,x_axis,fontsize=10,rotation=45)
plt.ylabel(TOP_CAP_YLABEL)
plt.show()

# %% [markdown]
# # Task No 6:

# %% [markdown]
# ## Volatility in cryptocurrencies

# %%
crypto_volatility=pd.read_csv('coinmarketcap_06122017.csv')
crypto_volatility=crypto_volatility[['id', 'percent_change_24h', 'percent_change_7d']].dropna(how='any')
crypto_volatility=crypto_volatility.set_index('id')
crypto_volatility=crypto_volatility.sort_values(by='percent_change_24h',ascending=True)
crypto_volatility=crypto_volatility.head(10)
crypto_volatility
# Out:
#                percent_change_24h  percent_change_7d
# id
# flappycoin                 -95.85             -96.61
# credence-coin              -94.22             -95.31
# coupecoin                  -93.93             -61.24
# tyrocoin                   -79.02             -87.43
# petrodollar                -76.55             542.96
# bitok                      -74.37             -71.67
# bankcoin                   -68.56              50.14
# tellurion                  -63.75             -52.59
# shadow-token               -61.40             -59.05
# eusd                       -58.89             -25.50

# %% [markdown]
# # Task No 7:

# %% [markdown]
# ## Well, we can already see that things are a bit crazy

# %%
def sub_plots(volatility,title):
    figure, axes =plt.subplots(nrows=1,ncols=2,figsize=(10,6))
    

    volatility=volatility[['id','percent_change_24h']].dropna().sort_values(by='percent_change_24h')
    lossers=volatility.head(10)

    
    axes[0].bar(lossers.id,lossers.percent_change_24h)
    axes[0].set_title("Losers",color='red')
    axes[0].set_ylabel('% change')
    axes[0].tick_params(rotation=90)
    
    winners=volatility.tail(10)
    
    axes[1].bar(winners.id,winners.percent_change_24h)
    axes[1].set_title("Winners",color='red')
    axes[1].set_ylabel('% change')
    axes[1].tick_params(rotation=90)
    plt.suptitle(title, fontsize=20)
    
DTITLE = "24 hours top losers and winners"
file =pd.read_csv('coinmarketcap_06122017.csv')

sub_plots(file,DTITLE)

# %% [markdown]
# # Task No 8:

# %% [markdown]
# ## Ok, those are... interesting. Let's check the weekly Series too.¶

# %%
def sub_plots_7d(volatility,title):
    figure, axes =plt.subplots(nrows=1,ncols=2,figsize=(15,8)
    

    volatility=volatility[['id','percent_change_7d']].dropna().sort_values(by='percent_change_7d')
    lossers=volatility.head(10)

    
    axes[0].bar(lossers.id,lossers.percent_change_7d)
    axes[0].set_title("Losers",color='red')
    axes[0].set_ylabel('% change')
    axes[0].tick_params(rotation=90)
    
    winners=volatility.tail(10)
    
    axes[1].bar(volatility.id[-10:],volatility.percent_change_7d[-10:])
    axes[1].set_title("Winners",color='red')
    axes[1].set_ylabel('% change')
    axes[1].tick_params(rotation=90)
    plt.suptitle(title, fontsize=20)
    
DTITLE = "Weekly top losers and winners"
volatility_7d =pd.read_csv('coinmarketcap_06122017.csv')

sub_plots_7d(volatility_7d,DTITLE)
# Out:
#   File "<ipython-input-96-dcd9a657ec97>", line 11
#     volatility=volatility[['id','percent_change_7d']].dropna().sort_values(by='percent_change_7d')
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Task No 9:

# %% [markdown]
# ## How small is small:

# %%
large_caps = dec_6.query('market_cap_usd > 10000000000')
large_caps['10 Billions'] = large_caps['market_cap_usd']/10000000000
print(large_caps[['id', '10 Billions']])
# Out:
#              id  10 Billions
# 0       bitcoin    21.304935
# 1      ethereum     4.352945
# 2  bitcoin-cash     2.529585
# 3          iota     1.475225
# c:\users\khawaja_osama\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# # Task No 10:

# %% [markdown]
# ## Most coins are tiny

# %%
file=pd.read_csv('coinmarketcap_06122017.csv').dropna()
capital=file[['id','market_cap_usd']]
capital=capital.dropna()

def captal_volume(small_volume,large_volume):
    if large_volume>small_volume:
        return len(capital[(capital['market_cap_usd'] >= small_volume) & (capital['market_cap_usd'] < large_volume)])
    
biggest = captal_volume(300000000, 500000000)
micro = captal_volume(50000000, 300000000)
nano = captal_volume(0, 50000000)
print('biggest',biggest)
print('micro',micro)
print('nano',nano)

labels=[ "micro", "nano","biggest"]
plt.bar(np.arange(3),[biggest,micro,nano])
plt.xticks(np.arange(3),labels)
# Out:
# biggest 4
# micro 25
# nano 145
# ([<matplotlib.axis.XTick at 0xaaed5d0>,
#   <matplotlib.axis.XTick at 0xc28890>,
#   <matplotlib.axis.XTick at 0xabdcd70>],
#  <a list of 3 Text xticklabel objects>)
